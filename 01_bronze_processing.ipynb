-- %%
CREATE OR REFRESH STREAMING LIVE TABLE 01_bronze.bridge_temperature
COMMENT "Raw temperature readings"
AS
SELECT *
FROM STREAM(delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_temperature`);

-- %%
CREATE OR REFRESH STREAMING LIVE TABLE 01_bronze.bridge_vibration
COMMENT "Raw vibration readings"
AS
SELECT *
FROM STREAM(delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_vibration`);

-- %%
CREATE OR REFRESH STREAMING LIVE TABLE 01_bronze.bridge_tilt
COMMENT "Raw tilt-angle readings"
AS
SELECT *
FROM STREAM(delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_tilt`);
